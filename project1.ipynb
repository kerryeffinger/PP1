# %% [markdown]
# # Programming Project 1
# ---
# **Author:** Kerry Effinger
# **Version:** 1.0
# **Semester:** Fall 2020
#
# This *notebook* contains my solution to **Programming Project 1**
#
# - Problem 1:  Awesome first solution.
# - Problem 2: Awesome second solution.
# - Problem 3: Awesome third solution.

# %%
from math import e

# %%
initial_pop = 89000000
growth_rate = .10
def exp_growth(initial_pop, growth_rate, years):
    """projects populations growth for certain time period"""
    return initial_pop * ((math.e) **(growth_rate*years))

for years in range (1,36,1):
    print (years)
    population = exp_growth (89000000,.1,years)
    increase = population - 89000000
    print(population)
    print(increase)
# Out:
# 1
# 98360211.70873265
# 9360211.70873265
# 2
# 108704845.47625512
# 19704845.47625512
# 3
# 120137433.87426428
# 31137433.874264285
# 4
# 132772398.09007306
# 43772398.090073064
# 5
# 146736193.0923114
# 57736193.09231141
# 6
# 162168573.2347553
# 73168573.2347553
# 7
# 179223990.96487242
# 90223990.96487242
# 8
# 198073142.6358296
# 109073142.6358296
# 9
# 218904676.8929685
# 129904676.8929685
# 10
# 241927082.73285502
# 152927082.73285502
# 11
# 267370776.13123256
# 178370776.13123256
# 12
# 295490406.12355274
# 206490406.12355274
# 13
# 326567403.4181127
# 237567403.4181127
# 14
# 360912797.04917604
# 271912797.04917604
# 15
# 398870327.2600877
# 309870327.2600877
# 16
# 440819885.77116525
# 351819885.77116525
# 17
# 487181317.8637208
# 398181317.8637208
# 18
# 538418624.3327521
# 449418624.3327521
# 19
# 595044605.362855
# 506044605.36285496
# 20
# 657625992.8048278
# 568625992.8048278
# 21
# 726789122.2185209
# 637789122.2185209
# 22
# 803226201.4496368
# 714226201.4496368
# 23
# ...

# %%
from prettytable import PrettyTable

x = PrettyTable()

x.header = True

print("Population Growth")

print("We started with 89,000,000 people")


column_names = ["Year", "Population", "Approximate Increase from Previous Year"]

x.add_column(column_names[0], [years])
x.add_column(column_names[1], [population])
x.add_column(column_names[2], [increase])

initial_pop = 89000000
growth_rate = .10
def exp_growth(initial_pop, growth_rate, years):
    """projects populations growth for certain time period"""
    return initial_pop * ((math.e) **(growth_rate*years))

for years in range (1,36,1):
    print (years)
    population = exp_growth (89000000,.1,years)
    increase = population - 89000000
    print(population)
    print(increase)
        
    print(x)
# Out:
# Population Growth
# We started with 89,000,000 people
# 1
# 98360211.70873265
# 9360211.70873265
# +------+-------------------+-----------------------------------------+
# | Year |     Population    | Approximate Increase from Previous Year |
# +------+-------------------+-----------------------------------------+
# |  35  | 2947275224.323615 |            2858275224.323615            |
# +------+-------------------+-----------------------------------------+
# 2
# 108704845.47625512
# 19704845.47625512
# +------+-------------------+-----------------------------------------+
# | Year |     Population    | Approximate Increase from Previous Year |
# +------+-------------------+-----------------------------------------+
# |  35  | 2947275224.323615 |            2858275224.323615            |
# +------+-------------------+-----------------------------------------+
# 3
# 120137433.87426428
# 31137433.874264285
# +------+-------------------+-----------------------------------------+
# ...
